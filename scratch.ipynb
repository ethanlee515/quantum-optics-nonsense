# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import qutip
import math
import cmath

# %%
ts = np.linspace(0, 10, 10)
xs = np.linspace(50, 150, 10)
ys = np.linspace(250, 350, 10)

# %%
plt.plot(xs, ys)
